# %%
# !nvidia-smi
# !pip install -q matplotlib-inline
# !apt update >/dev/null 2>&1
# !apt install -q -q -q -y -o Dpkg::Progress-Fancy="0" libgoogle-perftools-dev python3.10-venv

# %%
#!git clone https://github.com/AUTOMATIC1111/stable-diffusion-webui
#%cd /kaggle/working/stable-diffusion-webui
#%cd /kaggle/working/stable-diffusion-webui/extensions
#!git clone https://github.com/Mikubill/sd-webui-controlnet
#%cd /kaggle/working/stable-diffusion-webui

# %%
#!mkdir -v -p /kaggle/temp/checkpoints
#!mkdir -v -p /kaggle/temp/controlnet
#!mkdir -v -p /kaggle/temp/vae

#!cd /kaggle/temp/checkpoints && wget -nv -c https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/sd_xl_base_1.0.safetensors
#!cd /kaggle/temp/checkpoints && wget -T 3 --tries=1 --content-disposition -c 'https://civitai.com/api/download/models/731340?type=Model&format=SafeTensor&size=full&fp=fp16'
#!cd /kaggle/temp/controlnet && wget -nv -c https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_canny.pth
#!cd /kaggle/temp/controlnet && wget -nv --content-disposition -c https://huggingface.co/comfyanonymous/ControlNet-v1-1_fp16_safetensors/resolve/main/control_v11p_sd15_scribble_fp16.safetensors?download=true
#!cd /kaggle/temp/vae && wget -nv --content-disposition -c https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors?download=true
#!cd /kaggle/temp/checkpoints && wget -nv --content-disposition -c https://huggingface.co/Comfy-Org/stable-diffusion-v1-5-archive/resolve/main/v1-5-pruned-emaonly-fp16.safetensors?download=true
#https://huggingface.co/Comfy-Org/Qwen-Image_ComfyUI/resolve/main/split_files/diffusion_models/qwen_image_fp8_e4m3fn.safetensors
#!cd /kaggle/temp/diffusion_models && wget -nv -c --content-disposition https://huggingface.co/lightx2v/Qwen-Image-Lightning/resolve/main/Qwen-Image-Edit-2509/Qwen-Image-Edit-2509-Lightning-4steps-V1.0-bf16.safetensors

# %%
#!./webui.sh -f --xformers --share --ckpt-dir "/kaggle/temp/models" --enable-insecure-extension-access --no-half-vae

# %%
# %cd /kaggle/working
# !pip install -q torch torchvision torchaudio #--pre --index-url https://download.pytorch.org/whl/nightly/cu128
![ -d comfyui ] || git clone https://github.com/comfyanonymous/comfyui
# %cd /kaggle/working/comfyui
# !git fetch --tags; git reset --hard $(git tag | sort -V | tail -1)
![ -d custom_nodes/comfyui-manager ] || git -C custom_nodes clone https://github.com/ltdrdata/comfyui-manager
# !for custom_node in custom_nodes/*/; do git -C $custom_node pull; done
# !pip install -q -r requirements.txt
with open('extra_model_paths.yaml','wt') as pathcfg:
    pathcfg.write(r'''
comfyui:
     base_path: /kaggle/temp
     download_model_base: /kaggle/temp
     is_default: true
''')

# %%
# !npm install -g localtunnel
import os
# Start localtunnel in background
os.system("lt --port 8188 --subdomain comfyui-kaggle & echo Tunnel password: $(wget -q -O - https://loca.lt/mytunnelpassword)")

# !python main.py --listen 0.0.0.0 --port 8188
